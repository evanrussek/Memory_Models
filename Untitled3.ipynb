# %%
## started this...

include("MDPModelFunctions2.jl")
using BlackBoxOptim

#Random.seed!(1234);

which_group = "adult"

# array job stuff
is_array_job = false
run_idx = is_array_job ? parse(Int, ENV["SLURM_ARRAY_TASK_ID"]) : 1
on_cluster = false

# here's what we'll grid search over

# re-run with new values so we can see some concavity...
NT_vals = collect(100:250:2200)
mem_slopes = round.([.01*(1.5^x) for x = 2:9], digits = 3)


if on_cluster
    to_save_folder = "/home/erussek/projects/Memory_Models/shimi_bbopts"
else
    to_save_folder = "/Users/erussek/Dropbox/Griffiths_Lab_Stuff/code/Memory_Models/shimi_bbopts"
end


function format_res_cowan_k(res; exp_num = 1)
    
    if exp_num == 1
    
        # row is 2 obj vs 4 obj
        # col is pre-cue, neutral, retro-cue, neutral
        
        part_pcorr = res;
        model_cowan_p_corr = [part_pcorr; part_pcorr[2,:]']'
        model_cowan_k_mtx = cowan_k(model_cowan_p_corr, 2)
        model_cowan_k_mtx[2,:] = cowan_k(model_cowan_p_corr[2,:], 4)
        
        model_cowan_k = [model_cowan_k_mtx[1,:]' model_cowan_k_mtx[2,:]']';#[model_cowan_k_mtx[1,:] model_cowan_k_mtx[2,:]]
    elseif exp_num == 2
        
        # IM cued, IM neutral, VSTM cued, VSTM neutral - need to adjust from what it was saved as
        
        (p_short_neutral, p_short_retro, p_long_neutral, p_long_retro) = res
        model_cowan_k = cowan_k([p_short_retro p_short_neutral p_long_retro p_long_neutral],4)'
        
    else
        
        (p_IM_neutral, p_IM_retro, p_VSTM_neutral, p_VSTM_retro, p_Long_VSTM_neutral, p_Long_VSTM_retro) = res

        # Load 3 cued, Load 3 Neutral, Load 6 cued, Load 6 neutral
        IM_model = [cowan_k(p_IM_retro[1],3) cowan_k(p_IM_neutral[1],3) cowan_k(p_IM_retro[2],6) cowan_k(p_IM_neutral[2], 6)]
        Short_VSTM_model = [cowan_k(p_VSTM_retro[1],3) cowan_k(p_VSTM_neutral[1],3) cowan_k(p_VSTM_retro[2],6) cowan_k(p_VSTM_neutral[2], 6)]
        Long_VSTM_model = [cowan_k(p_Long_VSTM_retro[1],3) cowan_k(p_Long_VSTM_neutral[1],3) cowan_k(p_Long_VSTM_retro[2],6) cowan_k(p_Long_VSTM_neutral[2], 6)]

        # 3 x 4
        model_cowan_k = [IM_model; Short_VSTM_model; Long_VSTM_model]  
        
    end
        
    return model_cowan_k
    
end    


# 6 parameteres for 44 datapoints 

exp1_cowan_k_true_7_yr = [1.16 1.14 1.13 1.02 2.80 .91 1.30 .96]' # 8
exp1_cowan_k_true_adult = [1.98 1.94 1.97 1.95 3.87 2.66 3.64 2.87]'

# experiment 2 - 4 objects
# col is IM cued, IM neutral, VSTM cued, VSTM neutral

exp2_cowan_k_true_7_yr = [1.55 1.16 1.00 0.69]' # 4
exp2_cowan_k_true_adult = [3.54 2.58 3.58 2.65]'

# experiment 3

# Load 3 cued, Load 3 Neutral, Load 6 cued, Load 6 neutral
IM_true_7_yr = [1.44 1.27 1.82 0.88]
Short_VSTM_true_7_yr = [1.14 0.77 NaN NaN]
Long_VSTM_true_7_yr = [1.19 0.90 NaN NaN]

# 8

exp3_cowan_k_true_7_yr = [IM_true_7_yr; Short_VSTM_true_7_yr; Short_VSTM_true_7_yr]


IM_true_adult = [2.63 2.41 4.80 2.46]
Short_VSTM_true_adult = [2.75 2.38 3.97 2.15]
Long_VSTM_true_adult = [2.76 2.30 3.65 1.75]
# 12

exp3_cowan_k_true_adult = [IM_true_adult; Short_VSTM_true_adult; Short_VSTM_true_adult]

# function to compute mean squared error...

# takes in Adult_Quanta (int), Adult_Epsilon (0-1 bounded), Child_Quanta (int), Child_Epsilon (0-1 bounded), Mem_slope (less than 1), NT_val # 6 params...

# params = [20, .8, 5, .4, .1, 100]

function compute_mse(params, exp1_cowan_k_true_7_yr, exp1_cowan_k_true_adult, exp2_cowan_k_true_7_yr, exp2_cowan_k_true_adult, exp3_cowan_k_true_7_yr, exp3_cowan_k_true_adult; which_group = "adult", mem_slope = .01, nt_val = 100, N_Trials = 500)
    
    
    # garbage collect...
    GC.gc(true)
    
    

    if which_group == "adult"
        
        adult_quanta = round(100*params[1])
        adult_epsilon = params[2]
        
        adult_res_1 = sim_exp1(adult_epsilon, adult_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        adult_cowan_k1 = format_res_cowan_k(adult_res_1; exp_num = 1)
        adult_res_2 = sim_exp2(adult_epsilon, adult_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        adult_cowan_k2 = format_res_cowan_k(adult_res_2; exp_num = 2)
        adult_res_3 = sim_exp3(adult_epsilon, adult_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        
        
        adult_cowan_k3 = format_res_cowan_k(adult_res_3; exp_num = 3)

        adult_mse1 = sum((adult_cowan_k1 .- exp1_cowan_k_true_adult).^2)

        adult_mse2 = sum((adult_cowan_k2 .- exp2_cowan_k_true_adult).^2)

        #child_sq_err = (children_cowan_k3[:] .- exp3_cowan_k_true_7_yr[:]).^2
        #child_mse3 = sum(child_sq_err[.!isnan.(child_sq_err)])
        adult_mse3 = sum((adult_cowan_k3 .- exp3_cowan_k_true_adult).^2)

        #child_mse = child_mse1 + child_mse2 + child_mse3
        adult_mse = adult_mse1 + adult_mse2 + adult_mse3
        
        this_mse = adult_mse
        
    else
        
        child_quanta = round(100*params[1])
        adult_epsilon = params[2]
        
        children_res_1 = sim_exp1(child_epsilon, child_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        children_cowan_k1 = format_res_cowan_k(children_res_1; exp_num = 1)
        children_res_2 = sim_exp2(child_epsilon, child_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        children_cowan_k2 = format_res_cowan_k(children_res_2; exp_num = 2)
        children_res_3 = sim_exp3(child_epsilon, child_quanta, nt_val; mem_slope = mem_slope, N_Trials = N_Trials);
        children_cowan_k3 = format_res_cowan_k(children_res_3; exp_num = 3)
        
        child_mse1 = sum((children_cowan_k1 .- exp1_cowan_k_true_7_yr).^2)
        # adult_mse1 = sum((adult_cowan_k1 .- exp1_cowan_k_true_adult).^2)

        child_mse2 = sum((children_cowan_k2 .- exp2_cowan_k_true_7_yr).^2)
        #adult_mse2 = sum((adult_cowan_k2 .- exp2_cowan_k_true_adult).^2)

        child_sq_err = (children_cowan_k3[:] .- exp3_cowan_k_true_7_yr[:]).^2
        child_mse3 = sum(child_sq_err[.!isnan.(child_sq_err)])
        # adult_mse3 = sum((adult_cowan_k3 .- exp3_cowan_k_true_adult).^2)

        child_mse = child_mse1 + child_mse2 + child_mse3
        
        this_mse = child_mse
    end


    #both_mse = child_mse + adult_mse
    
    println(this_mse)
    
    return this_mse
    
end



target(params) = compute_mse(params, exp1_cowan_k_true_7_yr, exp1_cowan_k_true_adult, exp2_cowan_k_true_7_yr, exp2_cowan_k_true_adult, exp3_cowan_k_true_7_yr, exp3_cowan_k_true_adult, which_group = "adult", mem_slope = .2, nt_val = 1600, N_Trials = 500)
# Out:
# target (generic function with 1 method)

# %%
using Optim

# %%
lower = [0., 0.]
upper = [1., 1.]

x0 = [.5, .5]

function g(x,y)
    
    return 0
end


a = optimize(target, g, lower, upper, x0, Fminbox(NelderMead()), Optim.Options(show_trace = true, show_every = 1))
# Out:
# 28.01001669799163
# 43.60069448719341
# 25.831964352109253
# Fminbox
# -------
# Initial mu = NaN
#
# Fminbox iteration 1
# -------------------
# Calling inner optimizer with mu = NaN
#
# (numbers below include barrier contribution)
# 25.382563885792766
# Iter     Function value    √(Σ(yᵢ-ȳ)²)/n
# ------   --------------    --------------
#      0     2.583196e+01     7.913006e+00
#  * time: 4.696846008300781e-5
# 27.060195497532924
#
# Exiting inner optimizer with x = [0.5, 0.775]
# Current distance to box: 0.225
# Decreasing barrier term μ.
#
# 24.109192100034036
#  * Status: failure
#
#  * Candidate solution
#     Final objective value:     2.410919e+01
#
#  * Found with
#     Algorithm:     Fminbox with Nelder-Mead
#
#  * Convergence measures
#     |x - x'|               = 0.00e+00 ≤ 0.0e+00
#     |x - x'|/|x'|          = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   408  (vs limit Inf)
#     Iterations:    1
#     f(x) calls:    5
#     ∇f(x) calls:   1

# %%
?Optim.optimize
# Out:
#   No documentation found.
#
#   Optim.optimize is a Function.
#
#   # 67 methods for generic function "optimize" from Optim:
#     [1] optimize(d::D, initial_x::AbstractArray, method::Optim.SecondOrderOptimizer) where D<:Union{NonDifferentiable, OnceDifferentiable}
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:166
#     [2] optimize(d::D, initial_x::AbstractArray, method::Optim.SecondOrderOptimizer, options::Optim.Options; autodiff, inplace) where D<:Union{NonDifferentiable, OnceDifferentiable}
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:166
#     [3] optimize(d::TwiceDifferentiable, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:198
#     [4] optimize(d::TwiceDifferentiable, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:198
#     [5] optimize(::NLSolversBase.AbstractObjective, ::Method)
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:53
#     [6] optimize(::NLSolversBase.AbstractObjective, ::Method, ::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:56
#     [7] optimize(::NLSolversBase.AbstractObjective, ::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:59
#     [8] optimize(d::T, initial_x::AbstractArray, options::Optim.Options) where T<:NLSolversBase.AbstractObjective
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:115
#     [9] optimize(d::D, initial_x::Tx, method::M) where {D<:NLSolversBase.AbstractObjective, M<:Optim.AbstractOptimizer, Tx<:AbstractArray}
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/optimize.jl:32
#    [10] optimize(d::D, initial_x::Tx, method::M, options::Optim.Options{T, TCallback}) where {D<:NLSolversBase.AbstractObjective, M<:Optim.AbstractOptimizer, Tx<:AbstractArray, T, TCallback}
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/optimize.jl:32
#    [11] optimize(d::D, initial_x::Tx, method::M, options::Optim.Options{T, TCallback}, state) where {D<:NLSolversBase.AbstractObjective, M<:Optim.AbstractOptimizer, Tx<:AbstractArray, T, TCallback}
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/optimize.jl:32
#    [12] optimize(d::NLSolversBase.AbstractObjective, constraints::NLSolversBase.AbstractConstraints, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:220
#    [13] optimize(d::NLSolversBase.AbstractObjective, constraints::NLSolversBase.AbstractConstraints, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:220
#    [14] optimize(d::NLSolversBase.AbstractObjective, constraints::NLSolversBase.AbstractConstraints, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer, options::Optim.Options, state)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:220
#    [15] optimize(df::OnceDifferentiable, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray, F::Fminbox)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:272
#    [16] optimize(df::OnceDifferentiable, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray, F::Fminbox, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:272
#    [17] optimize(df::OnceDifferentiable, initial_x::Array{T}, l::Array{T}, u::Array{T}, ::Type{Fminbox}; x_tol, f_tol, g_tol, allow_f_increases, iterations, store_trace, show_trace, extended_trace, callback, show_every, linesearch, eta, mu0, mufactor, precondprep, optimizer, optimizer_o, nargs...) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:4
#    [18] optimize(df::OnceDifferentiable, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:272
#    [19] optimize(df::OnceDifferentiable, l::Array{T}, u::Array{T}, F::Fminbox{O}; kwargs...) where {T<:AbstractFloat, O<:Optim.AbstractOptimizer}
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:63
#    [20] optimize(::NLSolversBase.AbstractObjective)
#        @ ~/.julia/packages/Optim/V8ZEC/src/deprecate.jl:50
#    [21] optimize(f, initial_x::AbstractArray; inplace, autodiff, kwargs...)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:83
#    [22] optimize(f, g, l::AbstractArray, u::Number, initial_x::AbstractArray{T}, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:256
#    [23] optimize(f, g, l::AbstractArray{T}, u::AbstractArray{T}, initial_x::AbstractArray{T}) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:233
#    [24] optimize(f, g, l::AbstractArray{T}, u::AbstractArray{T}, initial_x::AbstractArray{T}, F::Fminbox) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:233
#    [25] optimize(f, g, l::AbstractArray{T}, u::AbstractArray{T}, initial_x::AbstractArray{T}, F::Fminbox, options; inplace, autodiff) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:233
#    [26] optimize(f, initial_x::AbstractArray, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:119
#    [27] optimize(f, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:259
#    [28] optimize(d, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:203
#    [29] optimize(obj_fn, lb::AbstractArray, ub::AbstractArray, x::AbstractArray{Tx}, method::SAMIN) where Tx
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/samin.jl:59
#    [30] optimize(obj_fn, lb::AbstractArray, ub::AbstractArray, x::AbstractArray{Tx}, method::SAMIN, options::Optim.Options) where Tx
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/samin.jl:59
#    [31] optimize(f, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray, F::Fminbox)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:259
#    [32] optimize(f, l::AbstractArray, u::AbstractArray, initial_x::AbstractArray, F::Fminbox, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:259
#    [33] optimize(d, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:203
#    [34] optimize(f, l::AbstractArray, u::Number, initial_x::AbstractArray{T}; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:248
#    [35] optimize(f, l::AbstractArray, u::Number, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:252
#    [36] optimize(f, l::AbstractArray, u::Number, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:252
#    [37] optimize(f, initial_x::AbstractArray, method::Optim.AbstractOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:139
#    [38] optimize(f, initial_x::AbstractArray, method::Optim.AbstractOptimizer, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:139
#    [39] optimize(f, c::NLSolversBase.AbstractConstraints, initial_x::AbstractArray, method::Optim.AbstractOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:145
#    [40] optimize(f, c::NLSolversBase.AbstractConstraints, initial_x::AbstractArray, method::Optim.AbstractOptimizer, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:145
#    [41] optimize(f, l::Number, u::AbstractArray, initial_x::AbstractArray{T}; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:249
#    [42] optimize(f, g, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:188
#    [43] optimize(f, g, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:188
#    [44] optimize(f, g, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:188
#    [45] optimize(f, l::Number, u::AbstractArray, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:253
#    [46] optimize(f, l::Number, u::AbstractArray, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:253
#    [47] optimize(f, g, initial_x::AbstractArray; inplace, autodiff, kwargs...)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:93
#    [48] optimize(f, g, initial_x::AbstractArray, method::Optim.AbstractOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:151
#    [49] optimize(f, g, initial_x::AbstractArray, method::Optim.AbstractOptimizer, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:151
#    [50] optimize(f, g, initial_x::AbstractArray, options::Optim.Options; inplace, autodiff)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:124
#    [51] optimize(f, x_lower::T, x_upper::T, mo::GoldenSection; rel_tol, abs_tol, iterations, store_trace, show_trace, callback, show_every, extended_trace, nargs...) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/univariate/solvers/golden_section.jl:21
#    [52] optimize(f, x_lower::T, x_upper::T, mo::Brent; rel_tol, abs_tol, iterations, store_trace, show_trace, callback, show_every, extended_trace) where T<:AbstractFloat
#        @ ~/.julia/packages/Optim/V8ZEC/src/univariate/solvers/brent.jl:23
#    [53] optimize(f, lower::T, upper::T; method, rel_tol, abs_tol, iterations, store_trace, show_trace, callback, show_every, extended_trace) where T<:Real
#        @ ~/.julia/packages/Optim/V8ZEC/src/univariate/optimize/interface.jl:2
#    [54] optimize(f, lower::Real, upper::Real; kwargs...)
#        @ ~/.julia/packages/Optim/V8ZEC/src/univariate/optimize/interface.jl:32
#    [55] optimize(f, g, l::Number, u::Number, initial_x::AbstractArray{T}, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:255
#    [56] optimize(f, l::Number, u::Number, initial_x::AbstractArray{T}; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:247
#    [57] optimize(f, g, h, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:193
#    [58] optimize(f, g, h, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:193
#    [59] optimize(f, g, h, lower::AbstractArray, upper::AbstractArray, initial_x::AbstractArray, method::Optim.ConstrainedOptimizer, options::Optim.Options)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/ipnewton/interior.jl:193
#    [60] optimize(f, g, l::Number, u::AbstractArray, initial_x::AbstractArray{T}, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:257
#    [61] optimize(f, l::Number, u::Number, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:251
#    [62] optimize(f, l::Number, u::Number, initial_x::AbstractArray{T}, mo::Optim.AbstractConstrainedOptimizer, opt::Optim.Options; kwargs...) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/solvers/constrained/fminbox.jl:251
#    [63] optimize(f, g, h, initial_x::AbstractArray; inplace, autodiff, kwargs...)
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:103
#    [64] optimize(f, g, h, initial_x::AbstractArray{T}, method::Optim.AbstractOptimizer) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:158
#    [65] optimize(f, g, h, initial_x::AbstractArray{T}, options::Optim.Options; inplace, autodiff) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:130
#    [66] optimize(f, g, h, initial_x::AbstractArray{T}, method::Optim.AbstractOptimizer, options::Optim.Options; inplace, autodiff) where T
#        @ ~/.julia/packages/Optim/V8ZEC/src/multivariate/optimize/interface.jl:158
#    [67] optimize(f, lower::Real, upper::Real, method::Union{Brent, GoldenSection}; kwargs...)
#        @ ~/.julia/packages/Optim/V8ZEC/src/univariate/optimize/interface.jl:44
